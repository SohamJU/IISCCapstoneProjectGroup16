# %%
# !python3 scripts/run_preprocessing.py --dataset twitter --twitter-path archive/twcs/twcs.csv
# Out:
# python3: can't open file '/content/scripts/run_preprocessing.py': [Errno 2] No such file or directory
