# %% [markdown]
# ## Setup

# %%
import sys
from pathlib import Path

# Ensure project root is on sys.path
PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Load environment variables
from dotenv import load_dotenv
load_dotenv(PROJECT_ROOT / ".env")

print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: c:\Users\gaura\Documents\GenAI Course\Capstone\IISCCapstoneProjectGroup16

# %% [markdown]
# using return_policy.md as policy, create a product return agent  which checks order details from orders.csv, customers-schema.json and return details from returns.csv, return.schema.json. Ask user if not enought information is provided. Implement similat to product_agent agent

# %%
from src.agents.return_agent import ProductReturnAgent

agent = ProductReturnAgent()

print("Policy summary:\n", agent.summarize(400))
print("\nHandle query example:\n", agent.handle_query("How do I return an item?"))
print("\nLookup order example (ORD-000001):\n", agent.lookup_order("ORD-000001"))
print("\nRAG-like query (restocking fee):\n", agent.rag_query("restocking fee"))
